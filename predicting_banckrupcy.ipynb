# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zCAnXhTHGrl1qoy1_7lHPAxf0PF_n0iJ' -O bank_rupcydata.csv
import pandas as pd

pd.read_csv('/content/bank_rupcydata.csv').head()
# Out:
# --2021-03-14 15:04:18--  https://docs.google.com/uc?export=download&id=1zCAnXhTHGrl1qoy1_7lHPAxf0PF_n0iJ
# Resolving docs.google.com (docs.google.com)... 172.217.218.139, 172.217.218.100, 172.217.218.113, ...
# Connecting to docs.google.com (docs.google.com)|172.217.218.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1ao0qpbdtulttndfr9ucnlsabf3r9lb1/1615734225000/16367067677858558621/*/1zCAnXhTHGrl1qoy1_7lHPAxf0PF_n0iJ?e=download [following]
# ...
# --2021-03-14 15:04:19--  https://doc-0g-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1ao0qpbdtulttndfr9ucnlsabf3r9lb1/1615734225000/16367067677858558621/*/1zCAnXhTHGrl1qoy1_7lHPAxf0PF_n0iJ?e=download
# Resolving doc-0g-ag-docs.googleusercontent.com (doc-0g-ag-docs.googleusercontent.com)... 108.177.119.132, 2a00:1450:4013:c00::84
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('bank_rupcydata.csv')
data
# Out:
#       Bankrupt?  ...   Equity to Liability
# 0             1  ...              0.016469
# 1             1  ...              0.020794
# 2             1  ...              0.016474
# 3             1  ...              0.023982
# 4             1  ...              0.035490
# ...         ...  ...                   ...
# 6814          0  ...              0.029890
# 6815          0  ...              0.038284
# 6816          0  ...              0.097649
# 6817          0  ...              0.044009
# 6818          0  ...              0.233902
#
# [6819 rows x 96 columns]

# %%
list=[' ROA(C) before interest and depreciation before interest',' ROA(B) before interest and depreciation after tax',' Pre-tax net Interest Rate',' Net Value Per Share (B)',' Net Value Per Share (C)',' Revenue Per Share (Yuan ¥)',' Operating Profit Per Share (Yuan ¥)',' Per Share Net profit before tax (Yuan ¥)',' Realized Sales Gross Profit Growth Rate',' After-tax Net Profit Growth Rate',' Operating Profit Growth Rate',' Current Ratio',' Quick Ratio',' Interest Expense Ratio',' Debt ratio %',' Net profit before tax/Paid-in capital',' Inventory Turnover Rate (times)', ' Fixed Assets Turnover Frequency',' Net Worth Turnover Rate (times)']
data=data.drop(list,axis=1)

# %%
data.columns
# Out:
# Index(['Bankrupt?', ' ROA(A) before interest and % after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (A)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Regular Net Profit Growth Rate',
#        ' Continuous Net Profit Growth Rate', ' Total Asset Growth Rate',
#        ' Net Value Growth Rate', ' Total Asset Return Growth Rate Ratio',
#        ' Cash Reinvestment %', ' Total debt/Total net worth',
#        ' Net worth/Assets', ' Long-term fund suitability ratio (A)',
#        ' Borrowing dependency', ' Contingent liabilities/Net worth',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 77 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Bankrupt?                                            6819 non-null   int64
#  1    ROA(A) before interest and % after tax              6819 non-null   float64
#  2    Operating Gross Margin                              6819 non-null   float64
#  3    Realized Sales Gross Margin                         6819 non-null   float64
#  4    Operating Profit Rate                               6819 non-null   float64
#  5    After-tax net Interest Rate                         6819 non-null   float64
#  6    Non-industry income and expenditure/revenue         6819 non-null   float64
#  7    Continuous interest rate (after tax)                6819 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['Bankrupt?', ' ROA(A) before interest and % after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (A)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Regular Net Profit Growth Rate',
#        ' Continuous Net Profit Growth Rate', ' Total Asset Growth Rate',
#        ' Net Value Growth Rate', ' Total Asset Return Growth Rate Ratio',
#        ' Cash Reinvestment %', ' Total debt/Total net worth',
#        ' Net worth/Assets', ' Long-term fund suitability ratio (A)',
#        ' Borrowing dependency', ' Contingent liabilities/Net worth',
# ...

# %%
data.shape
# Out:
# (6819, 77)

# %%
data.describe()
# Out:
#          Bankrupt?  ...   Equity to Liability
# count  6819.000000  ...           6819.000000
# mean      0.032263  ...              0.047578
# std       0.176710  ...              0.050014
# min       0.000000  ...              0.000000
# 25%       0.000000  ...              0.024477
# 50%       0.000000  ...              0.033798
# 75%       0.000000  ...              0.052838
# max       1.000000  ...              1.000000
#
# [8 rows x 77 columns]

# %%
data.isnull().sum()
# Out:
# Bankrupt?                                              0
#  ROA(A) before interest and % after tax                0
#  Operating Gross Margin                                0
#  Realized Sales Gross Margin                           0
#  Operating Profit Rate                                 0
#                                                       ..
#  Liability to Equity                                   0
#  Degree of Financial Leverage (DFL)                    0
#  Interest Coverage Ratio (Interest expense to EBIT)    0
#  Net Income Flag                                       0
#  Equity to Liability                                   0
# Length: 77, dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
x=data.drop('Bankrupt?',axis=1)
y=data['Bankrupt?']

# %%
x= x.loc[:,~x.columns.duplicated()]

# %%
f, ax=plt.subplots(figsize=(100,90))
correlation=x.corr()
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, linewidths=.5, fmt='.1f')

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 76 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0    ROA(A) before interest and % after tax              6819 non-null   float64
#  1    Operating Gross Margin                              6819 non-null   float64
#  2    Realized Sales Gross Margin                         6819 non-null   float64
#  3    Operating Profit Rate                               6819 non-null   float64
#  4    After-tax net Interest Rate                         6819 non-null   float64
#  5    Non-industry income and expenditure/revenue         6819 non-null   float64
#  6    Continuous interest rate (after tax)                6819 non-null   float64
#  7    Operating Expense Rate                              6819 non-null   float64
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
#X=scaler.fit_transform(x)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42)
X_trainscaled=scaler.fit_transform(X_train)
X_testscaled=scaler.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfclf=RandomForestClassifier(bootstrap=False)
#rfclf.fit(X_train, y_train)
rfclf.fit(X_trainscaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred=rfclf.predict(X_testscaled)

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test, y_pred)*100
print(acc,"%")
# Out:
# 96.89149560117302 %
